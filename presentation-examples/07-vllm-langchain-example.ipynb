# %%
# %pip install vllm
# %pip install langchain langchain-openai
# Out:
# Requirement already satisfied: vllm in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (0.6.3.post1)
# Requirement already satisfied: psutil in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (6.1.0)
# Requirement already satisfied: sentencepiece in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (0.2.0)
# Requirement already satisfied: numpy<2.0.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (1.26.4)
# Requirement already satisfied: requests>=2.26.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (2.32.3)
# Requirement already satisfied: tqdm in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (4.66.5)
# Requirement already satisfied: py-cpuinfo in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (9.0.0)
# Requirement already satisfied: transformers>=4.45.2 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (4.45.2)
# Requirement already satisfied: tokenizers>=0.19.1 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (0.20.1)
# Requirement already satisfied: protobuf in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (5.28.3)
# Requirement already satisfied: aiohttp in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (3.10.10)
# Requirement already satisfied: openai>=1.40.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (1.52.1)
# Requirement already satisfied: uvicorn[standard] in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (0.32.0)
# Requirement already satisfied: pydantic>=2.9 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (2.9.2)
# Requirement already satisfied: pillow in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (10.4.0)
# Requirement already satisfied: prometheus-client>=0.18.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (0.21.0)
# Requirement already satisfied: prometheus-fastapi-instrumentator>=7.0.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (7.0.0)
# Requirement already satisfied: tiktoken>=0.6.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (0.7.0)
# Requirement already satisfied: lm-format-enforcer==0.10.6 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (0.10.6)
# Requirement already satisfied: outlines<0.1,>=0.0.43 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (0.0.46)
# Requirement already satisfied: typing-extensions>=4.10 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (4.12.2)
# Requirement already satisfied: filelock>=3.10.4 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (3.16.1)
# Requirement already satisfied: partial-json-parser in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (0.2.1.1.post4)
# Requirement already satisfied: pyzmq in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (26.2.0)
# Requirement already satisfied: msgspec in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (0.18.6)
# Requirement already satisfied: gguf==0.10.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (0.10.0)
# Requirement already satisfied: importlib-metadata in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (8.5.0)
# Requirement already satisfied: mistral-common>=1.4.4 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from mistral-common[opencv]>=1.4.4->vllm) (1.4.4)
# Requirement already satisfied: pyyaml in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (6.0.2)
# Requirement already satisfied: einops in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (0.8.0)
# Requirement already satisfied: compressed-tensors==0.6.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (0.6.0)
# Requirement already satisfied: ray>=2.9 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (2.37.0)
# Requirement already satisfied: nvidia-ml-py in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (12.560.30)
# Requirement already satisfied: torch==2.4.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (2.4.0)
# Requirement already satisfied: torchvision==0.19 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (0.19.0)
# Requirement already satisfied: xformers==0.0.27.post2 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (0.0.27.post2)
# Requirement already satisfied: six>=1.16.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (1.16.0)
# Requirement already satisfied: setuptools>=74.1.1 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (75.2.0)
# Requirement already satisfied: fastapi!=0.113.*,!=0.114.0,>=0.107.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from vllm) (0.115.3)
# Requirement already satisfied: interegular>=0.3.2 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from lm-format-enforcer==0.10.6->vllm) (0.3.3)
# Requirement already satisfied: packaging in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from lm-format-enforcer==0.10.6->vllm) (24.1)
# Requirement already satisfied: sympy in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from torch==2.4.0->vllm) (1.13.3)
# Requirement already satisfied: networkx in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from torch==2.4.0->vllm) (3.4.2)
# Requirement already satisfied: jinja2 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from torch==2.4.0->vllm) (3.1.4)
# Requirement already satisfied: fsspec in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from torch==2.4.0->vllm) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from torch==2.4.0->vllm) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from torch==2.4.0->vllm) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from torch==2.4.0->vllm) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from torch==2.4.0->vllm) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from torch==2.4.0->vllm) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from torch==2.4.0->vllm) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from torch==2.4.0->vllm) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from torch==2.4.0->vllm) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from torch==2.4.0->vllm) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from torch==2.4.0->vllm) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from torch==2.4.0->vllm) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from torch==2.4.0->vllm) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.4.0->vllm) (12.6.77)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from fastapi!=0.113.*,!=0.114.0,>=0.107.0->vllm) (0.41.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.21.1 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from mistral-common>=1.4.4->mistral-common[opencv]>=1.4.4->vllm) (4.23.0)
# Requirement already satisfied: opencv-python-headless<5.0.0,>=4.0.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from mistral-common[opencv]>=1.4.4->vllm) (4.10.0.84)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from openai>=1.40.0->vllm) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from openai>=1.40.0->vllm) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from openai>=1.40.0->vllm) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from openai>=1.40.0->vllm) (0.6.1)
# Requirement already satisfied: sniffio in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from openai>=1.40.0->vllm) (1.3.1)
# Requirement already satisfied: lark in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from outlines<0.1,>=0.0.43->vllm) (1.2.2)
# Requirement already satisfied: nest-asyncio in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from outlines<0.1,>=0.0.43->vllm) (1.6.0)
# Requirement already satisfied: cloudpickle in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from outlines<0.1,>=0.0.43->vllm) (3.1.0)
# Requirement already satisfied: diskcache in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from outlines<0.1,>=0.0.43->vllm) (5.6.3)
# Requirement already satisfied: numba in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from outlines<0.1,>=0.0.43->vllm) (0.60.0)
# Requirement already satisfied: referencing in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from outlines<0.1,>=0.0.43->vllm) (0.35.1)
# Requirement already satisfied: datasets in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from outlines<0.1,>=0.0.43->vllm) (3.0.2)
# Requirement already satisfied: pycountry in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from outlines<0.1,>=0.0.43->vllm) (24.6.1)
# Requirement already satisfied: pyairports in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from outlines<0.1,>=0.0.43->vllm) (2.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from pydantic>=2.9->vllm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from pydantic>=2.9->vllm) (2.23.4)
# Requirement already satisfied: click>=7.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from ray>=2.9->vllm) (8.1.7)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from ray>=2.9->vllm) (1.1.0)
# Requirement already satisfied: aiosignal in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from ray>=2.9->vllm) (1.3.1)
# Requirement already satisfied: frozenlist in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from ray>=2.9->vllm) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from requests>=2.26.0->vllm) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from requests>=2.26.0->vllm) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from requests>=2.26.0->vllm) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from requests>=2.26.0->vllm) (2024.8.30)
# Requirement already satisfied: regex>=2022.1.18 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from tiktoken>=0.6.0->vllm) (2024.9.11)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from tokenizers>=0.19.1->vllm) (0.26.1)
# Requirement already satisfied: safetensors>=0.4.1 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from transformers>=4.45.2->vllm) (0.4.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from aiohttp->vllm) (2.4.3)
# Requirement already satisfied: attrs>=17.3.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from aiohttp->vllm) (24.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from aiohttp->vllm) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from aiohttp->vllm) (1.16.0)
# Requirement already satisfied: zipp>=3.20 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from importlib-metadata->vllm) (3.20.2)
# Requirement already satisfied: h11>=0.8 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from uvicorn[standard]->vllm) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from uvicorn[standard]->vllm) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from uvicorn[standard]->vllm) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from uvicorn[standard]->vllm) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from uvicorn[standard]->vllm) (0.24.0)
# Requirement already satisfied: websockets>=10.4 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from uvicorn[standard]->vllm) (13.1)
# Requirement already satisfied: httpcore==1.* in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai>=1.40.0->vllm) (1.0.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.21.1->mistral-common>=1.4.4->mistral-common[opencv]>=1.4.4->vllm) (2024.10.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.21.1->mistral-common>=1.4.4->mistral-common[opencv]>=1.4.4->vllm) (0.20.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from yarl<2.0,>=1.12.0->aiohttp->vllm) (0.2.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from datasets->outlines<0.1,>=0.0.43->vllm) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from datasets->outlines<0.1,>=0.0.43->vllm) (0.3.8)
# Requirement already satisfied: pandas in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from datasets->outlines<0.1,>=0.0.43->vllm) (2.2.3)
# Requirement already satisfied: xxhash in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from datasets->outlines<0.1,>=0.0.43->vllm) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from datasets->outlines<0.1,>=0.0.43->vllm) (0.70.16)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from jinja2->torch==2.4.0->vllm) (3.0.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from numba->outlines<0.1,>=0.0.43->vllm) (0.43.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from sympy->torch==2.4.0->vllm) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from pandas->datasets->outlines<0.1,>=0.0.43->vllm) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from pandas->datasets->outlines<0.1,>=0.0.43->vllm) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from pandas->datasets->outlines<0.1,>=0.0.43->vllm) (2024.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (0.3.4)
# Requirement already satisfied: langchain-openai in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (0.2.3)
# Requirement already satisfied: PyYAML>=5.3 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from langchain) (3.10.10)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.12 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from langchain) (0.3.12)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from langchain) (0.3.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from langchain) (0.1.137)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from langchain) (9.0.0)
# Requirement already satisfied: openai<2.0.0,>=1.52.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from langchain-openai) (1.52.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from langchain-openai) (0.7.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.16.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.12->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.12->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.12->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.10)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.52.0->langchain-openai) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.52.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.52.0->langchain-openai) (0.6.1)
# Requirement already satisfied: sniffio in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.52.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.52.0->langchain-openai) (4.66.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: regex>=2022.1.18 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.9.11)
# Requirement already satisfied: httpcore==1.* in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.12->langchain) (3.0.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/ubuntu/ai-workshop-materials/.venv/lib/python3.12/site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(base_url="http://localhost:8000/v1",
                 model="meta-llama/Llama-3.2-3B-Instruct",
                 api_key="abc1234")

# %%
from langchain_core.messages import SystemMessage, HumanMessage

messages = [
    SystemMessage("You are a helpful assistant."),
    HumanMessage("Please give me a brief history of Tennessee in a single paragraph.")
]

print(llm.invoke(messages))
# Out:
# content='Tennessee, known as the "Volunteer State," has a rich and diverse history spanning thousands of years. The region was first inhabited by Native American tribes, including the Cherokee, Chickasaw, and Creek. In 1540, Spanish explorer Hernando de Soto became the first European to visit the area. In 1769, the British established the Colony of North Carolina, which included present-day Tennessee. The state\'s name originated from the Iroquois word "tanasi," meaning "meeting place," which refers to the confluence of the Tennessee and Cumberland rivers. In 1796, the Southwest Territory was established, and in 1796, the first state constitution was adopted, paving the way for Tennessee\'s statehood in 1796. Throughout its history, Tennessee has played a significant role in the Civil War, the music industry, and the Civil Rights Movement, earning its reputation as a unique and influential state in American history.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 194, 'prompt_tokens': 54, 'total_tokens': 248, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'meta-llama/Llama-3.2-3B-Instruct', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-9dd17925-d3b5-4596-97fd-4bd807d40319-0' usage_metadata={'input_tokens': 54, 'output_tokens': 194, 'total_tokens': 248, 'input_token_details': {}, 'output_token_details': {}}
